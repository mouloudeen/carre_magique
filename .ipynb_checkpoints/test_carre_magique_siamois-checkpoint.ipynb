# %% [markdown]
# ## Test du modele avec nord-ouest

# %% [markdown]
# ### Fonction pour créer un carré magique de facon siamois nord-ouest

# %%
def carre_siamois(n,k):
    carre = [[0 for i in range(n)] for j in range(n)]
    l = 1
    i = 0 
    j = (n-1)/2
    carre[i][j] = k
    while l != n*n:
        if (carre[(i - 1) % n][(j + 1) % n] != 0):
            j = (j + 1) % n
            k += 1
            carre[i][j] = k
            l += 1
        i = (i - 1) % n
        j = (j + 1) % n
        k += 1
        carre[i][j] = k
        l += 1
    return carre

# %%
# calculer la somme d'une colonne
def sum_col(carre, indice, n):
    somme = 0
    for j in range(n):
        somme += carre[indice][j]
    return somme

# %%
# calculer la somme de la diagonale qui part de en haut à gauche vers en bas à droite
def sum_diag1(carre,n):
    somme = 0
    for i in range(n):
        somme += carre[i][i]
    return somme

# %%
# calculer la somme de la diagonale qui part de en haut à droite vers en bas à gauche
def sum_diag2(carre,n):
    somme = 0
    for i in range(n):
        somme += carre[i][n-1-i]
    return somme

# %%
def carre_is_magic(carre,n):
    for i in range(n-1):
        if sum(carre[i]) != sum(carre[i+1]):
            return false
    for i in range(n-1):
        if sum_col(carre, i, n) != sum_col(carre, i+1, n):
            return false
    if sum_diag1(carre,n) != sum_diag2(carre,n):
        return false
    i = randint(1,n-1)
    j = randint(1,n-1)
    if sum(carre[i]) != sum_col(carre, j, n) or sum(carre[i]) != sum_diag1(carre,n):
        return false
    return true

# %%
# exemple d'un carré siamois d'ordre 13

# %%
carre = carre_siamois(13,4); carre
# Out:
# [[102, 116, 130, 144, 158, 172, 4, 18, 32, 46, 60, 74, 88],
#  [115, 129, 143, 157, 171, 16, 17, 31, 45, 59, 73, 87, 101],
#  [128, 142, 156, 170, 15, 29, 30, 44, 58, 72, 86, 100, 114],
#  [141, 155, 169, 14, 28, 42, 43, 57, 71, 85, 99, 113, 127],
#  [154, 168, 13, 27, 41, 55, 56, 70, 84, 98, 112, 126, 140],
#  [167, 12, 26, 40, 54, 68, 69, 83, 97, 111, 125, 139, 153],
#  [11, 25, 39, 53, 67, 81, 82, 96, 110, 124, 138, 152, 166],
#  [24, 38, 52, 66, 80, 94, 95, 109, 123, 137, 151, 165, 10],
#  [37, 51, 65, 79, 93, 107, 108, 122, 136, 150, 164, 9, 23],
#  [50, 64, 78, 92, 106, 120, 121, 135, 149, 163, 8, 22, 36],
#  [63, 77, 91, 105, 119, 133, 134, 148, 162, 7, 21, 35, 49],
#  [76, 90, 104, 118, 132, 146, 147, 161, 6, 20, 34, 48, 62],
#  [89, 103, 117, 131, 145, 159, 160, 5, 19, 33, 47, 61, 75]]

# %%
#verification avec un test pour vois si c'est bien un carré magique
# on teste avec un order 1331

# %%
carre = carre_siamois(1331,4)

# %%
# verification pour les lignes

# %%
for i in range(1330):
    if sum(carre[i]) != sum(carre[i+1]):
        print("false")
print(" true")
# Out:
#  true

# %%
# verification pour les colonnes

# %%
for i in range(1330):
    if sum_col(carre, i, 1331) != sum_col(carre, i+1, 1331):
        print("false")
print(" true")
# Out:
#  true

# %%
#verification par diagonale

# %%
sum_diag1(carre,1331) == sum_diag2(carre,1331)
# Out:
# True

# %%
# vérification d'une ligne avec une colonne et aussi avec une diagonale

# %%
i = randint(1,133)
j = randint(1,133)

# %%
sum(carre[i]) == sum_col(carre, j, 1331) and sum(carre[i]) == sum_diag1(carre,133)
# Out:
# True

# %%
#essaie avec la fonction carre_is_magic

# %%
carre_is_magic(carre,1331)
# Out:
# True

# %%
## un test pour plusieurs ordre impaires

# %%
for i in range(10):
    n = randint(1,10000)
    while (n%2 != 1):
        n = randint(1,10000)
    k = randint(1,10000)
    print(n,k)
    
    carre = carre_siamois(n,k)
    if carre_is_magic(carre,n) == false:
        print("false")
print("true")
# Out:
# 5465 4656
# 2045 1023
# 9197 9629
# 9613 6443
# 8489 2859
# 953 765
# 7265 7440
# 7259 7773
# 4771 4704
# 8009 6668
# true
